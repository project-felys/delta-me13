# %%
import seaborn as sns
import json


def metrics(path: str):
    with open(path) as f:
        data = json.load(f)

    sns.histplot(data, multiple="stack")
    return sum(sum(x) for x in data.values())

# %%
metrics("corpora/pt/everything.json")
# Out:
# 104252112

# %%
metrics("corpora/pt/amphoreus.json")
# Out:
# 16955351

# %%
metrics("corpora/pt/vendor.json")
# Out:
# 8716012

# %%
metrics("corpora/sft/everything.json")
# Out:
# 201002414

# %%
metrics("corpora/sft/amphoreus.json")
# Out:
# 31522921

# %%
metrics("corpora/sft/cyrene.json")
# Out:
# 2424011

# %%
metrics("corpora/tts/cyrene.json")
# Out:
# 318693
