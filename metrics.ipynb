# %%
import seaborn as sns
import json

# %%
with open("corpora/pt/everything.json") as f:
    metrics = json.load(f)

sns.histplot(metrics, multiple="stack")
# Out:
# <Axes: ylabel='Count'>

# %%
with open("corpora/pt/amphoreus.json") as f:
    metrics = json.load(f)

sns.histplot(metrics, multiple="stack")
# Out:
# <Axes: ylabel='Count'>

# %%
with open("corpora/pt/vendor.json") as f:
    metrics = json.load(f)

sns.histplot(metrics, multiple="stack")
# Out:
# <Axes: ylabel='Count'>

# %%
with open("corpora/sft/everything.json") as f:
    metrics = json.load(f)

sns.histplot(metrics, multiple="stack")
# Out:
# <Axes: ylabel='Count'>

# %%
with open("corpora/sft/amphoreus.json") as f:
    metrics = json.load(f)

sns.histplot(metrics, multiple="stack")
# Out:
# <Axes: ylabel='Count'>

# %%
with open("corpora/sft/cyrene.json") as f:
    metrics = json.load(f)

sns.histplot(metrics, multiple="stack")
# Out:
# <Axes: ylabel='Count'>
