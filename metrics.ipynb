# %%
import seaborn as sns
import json

# %%
with open("corpora/pt.json") as f:
    metrics = json.load(f)

sns.histplot(metrics, multiple="stack")
# Out:
# <Axes: ylabel='Count'>

# %%
with open("corpora/amphoreus.json") as f:
    metrics = json.load(f)

sns.histplot(metrics, multiple="stack")
# Out:
# <Axes: ylabel='Count'>

# %%
with open("corpora/vendor.json") as f:
    metrics = json.load(f)

sns.histplot(metrics, multiple="stack")
# Out:
# <Axes: ylabel='Count'>

# %%
with open("corpora/sft.json") as f:
    metrics = json.load(f)

sns.histplot(metrics, multiple="stack")
# Out:
# <Axes: ylabel='Count'>

# %%
with open("corpora/cyrene.json") as f:
    metrics = json.load(f)

sns.histplot(metrics, multiple="stack")
# Out:
# <Axes: ylabel='Count'>
